# %%
# подключение библиотек
import numpy as np
import pandas as pd

from statsmodels.formula.api import ols

# Не показывать Warnings
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
# импорт данных из файла как DataFrame
df = pd.read_csv('sleep75.csv')

# %% [markdown]
# 1.1 Sleep equation
# Для датасета sleep75 рассмотрим регрессию sleep на totwrk, age, male, smsa
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
# спецификация модели через формулу
mod = ols(formula='sleep~1+totwrk+age+male+smsa', data=df)
# подгонка модели
res = mod.fit()

# %%
# параметры подогнанной модели регрессии
res.params
# Out:
# Intercept    3494.223143
# totwrk         -0.167681
# age             2.806498
# male           86.908377
# smsa          -75.285755
# dtype: float64

# %% [markdown]
# Для наблюдений с индексом 0, 3, 5, 9, 507, 699 найдите фактическое значение зависимой переменной, предсказанное значение и остатки.

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [0, 3, 5, 9, 507, 699]

# %%
# Фактические значения
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
df['sleep'].iloc[ind]
# Out:
# 0      3113
# 3      3083
# 5      4063
# 9      3018
# 507    3630
# 699    2993
# Name: sleep, dtype: int64

# %%
# Предсказанные значения
res.fittedvalues[ind]
# Out:
# 0      3094.453743
# 3      2943.579539
# 5      3494.142891
# 9      3111.983473
# 507    3476.913947
# 699    3295.398425
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid[ind]
# Out:
# 0       18.546257
# 3      139.420461
# 5      568.857109
# 9      -93.983473
# 507    153.086053
# 699   -302.398425
# dtype: float64

# %% [markdown]
# Вычислите TSS, ESS, RSS

# %%
# TSS
res.centered_tss
# Out:
# np.float64(139239835.76345608)

# %%
# ESS
res.ess
# Out:
# np.float64(17188382.23361732)

# %%
# RSS
res.ssr
# Out:
# np.float64(122051453.52983876)

# %%
# коэф R^2
res.rsquared
# Out:
# np.float64(0.12344443053507581)

# %%
# adj R^2 жетерменации
res.rsquared_adj
# Out:
# np.float64(0.11844268691473392)

# %% [markdown]
# Вычислите R2
#  и adj.R2 и стандарт ошибку регрессии

# %%
# R^2
res.rsquared
# Out:
# np.float64(0.12344443053507581)

# %%
# adj R^2
res.rsquared_adj
# Out:
# np.float64(0.11844268691473392)

# %%
# стандартная ошибка регрессии
res.scale**0.5
# Out:
# np.float64(417.26549109269905)

# %% [markdown]
# 1.2 Sleep equation (smsa only)
# Для датасета sleep75 рассмотрим регрессию sleep на totwrk, age, male, south только для жителей мегаполиса (smsa=1)
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
df_new = df[df['smsa']==1].reset_index(drop=True)
# сброс индексов

# %%
# спецификация модели через формулу
mod = ols(formula='sleep~1+totwrk+age+male+south', data=df_new)
# подгонка модели
res = mod.fit()

# %%
# параметры подогнанной модели регрессии
res.params
# Out:
# Intercept    3460.427182
# totwrk         -0.184996
# age             2.276770
# male           92.649951
# south         168.852598
# dtype: float64

# %% [markdown]
# Для наблюдений с индексом 0, 8, 55, 75, 99 найдите фактическое значение зависимой переменной, предсказанное значение и остатки.

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [0, 8, 55, 75, 99]

# %%
# Фактические значения
# тут  мы пишем для новых данных
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
df_new['sleep'].iloc[ind]
# Out:
# 0     2670
# 8     3090
# 55    2985
# 75    3660
# 99    2618
# Name: sleep, dtype: int64

# %%
# Предсказанные значения
res.fittedvalues.iloc[ind]
# Out:
# 0     3132.491381
# 8     3370.083016
# 55    2835.360127
# 75    3248.539519
# 99    2863.069846
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid.iloc[ind]
# Out:
# 0    -462.491381
# 8    -280.083016
# 55    149.639873
# 75    411.460481
# 99   -245.069846
# dtype: float64

# %%
# TSS
res.centered_tss
# Out:
# np.float64(50055043.404255316)

# %%
# ESS
res.ess
# Out:
# np.float64(7396259.393412963)

# %%
# RSS
res.ssr
# Out:
# np.float64(42658784.01084235)

# %%
# R^2
res.rsquared
# Out:
# np.float64(0.14776252082490826)

# %%
# adj R^2
res.rsquared_adj
# Out:
# np.float64(0.13545584242526798)

# %%
# стандартная ошибка регрессии
res.scale**0.5
# Out:
# np.float64(392.4319436081266)

# %% [markdown]
# 1.3 Sleep equation (men only)
# Для датасета sleep75 рассмотрим регрессию sleep на totwrk, age, smsa, south только для мужчин (male=1)
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
df_new = df[df['male']==1].reset_index(drop=True)
# сброс индексов, ток мужики

# %%
# спецификация модели через формулу
mod = ols(formula='sleep~1+totwrk+age+smsa+south', data=df_new)
# подгонка модели
res = mod.fit()

# %%
# параметры подогнанной модели регрессии
res.params
# Out:
# Intercept    3600.958512
# totwrk         -0.187650
# age             3.301936
# smsa          -77.686142
# south          60.113665
# dtype: float64

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [ 0, 8, 44, 186, 279]

# %%
# Фактические значения
# тут  мы пишем для новых данных
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
df_new['sleep'].iloc[ind]
# Out:
# 0      3113
# 8      3018
# 44     3363
# 186    3390
# 279    2955
# Name: sleep, dtype: int64

# %%
# Предсказанные значения
res.fittedvalues.iloc[ind]
# Out:
# 0      3061.480989
# 8      3087.341316
# 44     3268.520837
# 186    3228.976363
# 279    3399.060021
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid.iloc[ind]
# Out:
# 0       51.519011
# 8      -69.341316
# 44      94.479163
# 186    161.023637
# 279   -444.060021
# dtype: float64

# %%
# TSS
res.centered_tss
# Out:
# np.float64(75570140.57750002)

# %%
# ESS
res.ess
# Out:
# np.float64(12125135.59786518)

# %%
# RSS
res.ssr
# Out:
# np.float64(63445004.97963484)

# %% [markdown]
# Вычислите R2
#  и adj.R2

# %%
# R^2
res.rsquared
# Out:
# np.float64(0.16044876329732904)

# %%
# R^2 adjh
res.rsquared_adj
# Out:
# np.float64(0.1519469786218589)

# %%
# стандартная ошибка регрессии
res.scale**0.5
# Out:
# np.float64(400.7745822419723)

# %% [markdown]
# 1.4 Sleep equation (women only)
# Для датасета sleep75 рассмотрим регрессию sleep на totwrk, age, smsa, south только для женщин (male=0)
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
df_new = df[df['male']==0].reset_index(drop=True)
# сброс индексов, ток women

# %%
# спецификация модели через формулу
mod = ols(formula='sleep~1+totwrk+age+smsa+south', data=df_new)
# подгонка модели
res = mod.fit()

# %%
# параметры подогнанной модели регрессии
res.params
# Out:
# Intercept    3468.202663
# totwrk         -0.150993
# age             1.645390
# smsa          -37.687393
# south         136.029203
# dtype: float64

# %% [markdown]
# Для наблюдений с индексом 0, 8, 44, 186, 279 найдите фактическое значение зависимой переменной, предсказанное значение и остатки.

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [0, 8, 44, 186, 279]

# %%
# Фактические значения
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
df_new['sleep'].iloc[ind]
# Out:
# 0      3083
# 8      2858
# 44     3730
# 186    3376
# 279    3405
# Name: sleep, dtype: int64

# %%
# Предсказанные значения
res.fittedvalues[ind]
# Out:
# 0      2945.903009
# 8      2920.661595
# 44     3328.629277
# 186    3503.721925
# 279    3215.073387
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid[ind]
# Out:
# 0      137.096991
# 8      -62.661595
# 44     401.370723
# 186   -127.721925
# 279    189.926613
# dtype: float64

# %% [markdown]
# Вычислите TSS, ESS, RSS

# %%
# TSS
res.centered_tss
# Out:
# np.float64(63490152.11764705)

# %%
# ESS
res.ess
# Out:
# np.float64(6300990.568985932)

# %%
# RSS
res.ssr
# Out:
# np.float64(57189161.54866112)

# %% [markdown]
# Вычислите R2
#  и adj.R2 b miustake

# %%
# R^2
res.rsquared
# Out:
# np.float64(0.09924358910512954)

# %%
# adj R^2
res.rsquared_adj
# Out:
# np.float64(0.0872734042427391)

# %%
# стандартная ошибка регрессии
res.scale**0.5
# Out:
# np.float64(435.8866990943623)

# %% [markdown]
# 1.5 Labour equation (in levels)
# Для датасета Labour рассмотрим регрессию output на capital, labour, wage
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
# импорт данных из файла как DataFrame
df = pd.read_csv('Labour.csv')

# %%
# спецификация модели через формулу
mod = ols(formula='output~1+capital+labour+wage', data=df)
# подгонка модели
res = mod.fit()

# %%
# параметры подогнанной модели регрессии
res.params
# Out:
# Intercept   -16.745898
# capital       0.395074
# labour        0.049899
# wage          0.436984
# dtype: float64

# %% [markdown]
# Для наблюдений с индексом 1, 10, 23, 100, 348, 500 найдите фактическое значение зависимой переменной, предсказанное значение и остатки.

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [ 1, 10, 23, 100, 348, 500 ]

# %%
# Фактические значения
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
df['output'].iloc[ind]
# Out:
# 1      3.664310
# 10     3.245624
# 23     2.666305
# 100    2.180688
# 348    4.307089
# 500    3.659600
# Name: output, dtype: float64

# %%
# Предсказанные значения
res.fittedvalues[ind]
# Out:
# 1       0.457101
# 10      5.665641
# 23     -0.625486
# 100     6.952054
# 348     2.278341
# 500    11.353485
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid[ind]
# Out:
# 1      3.207209
# 10    -2.420017
# 23     3.291791
# 100   -4.771366
# 348    2.028748
# 500   -7.693885
# dtype: float64

# %% [markdown]
# Вычислите TSS, ESS, RSS

# %%
# TSS
res.centered_tss
# Out:
# np.float64(2235073.2947312016)

# %%
# ESS
res.ess
# Out:
# np.float64(2190376.0767236855)

# %%
# RSS
res.ssr
# Out:
# np.float64(44697.21800751614)

# %% [markdown]
# Вычислите R2
#  и adj.R2

# %%
# R^2
res.rsquared
# Out:
# np.float64(0.9800019005583029)

# %%
# adj R^2
res.rsquared_adj
# Out:
# np.float64(0.9798957159594974)

# %%
# стандартная ошибка регрессии
res.scale**0.5
# Out:
# np.float64(8.894387014701193)

# %% [markdown]
# 1.6 Labour equation (in log)
# Для датасета Labour рассмотрим регрессию log(output) на log(capital), log(labour), log(wage)
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
# спецификация модели через формулу
mod = ols(formula='np.log(output)~1+np.log(capital)+np.log(labour)+np.log(wage)', data=df)
# подгонка модели
res = mod.fit()

# %%
# параметры подогнанной модели регрессии
res.params
# Out:
# Intercept         -5.007316
# np.log(capital)    0.149343
# np.log(labour)     0.720410
# np.log(wage)       0.921390
# dtype: float64

# %% [markdown]
# Для наблюдений с индексом 1, 10, 23, 100, 348, 500 найдите фактическое значение зависимой переменной, предсказанное значение и остатки.

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [ 1, 10, 23, 100, 348, 500]

# %%
# Фактические значения
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
np.log(df['output']).iloc[ind]
# Out:
# 1      1.298640
# 10     1.177308
# 23     0.980694
# 100    0.779641
# 348    1.460262
# 500    1.297354
# Name: output, dtype: float64

# %%
# Предсказанные значения
res.fittedvalues[ind]
# Out:
# 1      1.347170
# 10     1.426914
# 23     0.343786
# 100    1.005545
# 348    1.177214
# 500    1.730432
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid[ind]
# Out:
# 1     -0.048530
# 10    -0.249606
# 23     0.636907
# 100   -0.225905
# 348    0.283048
# 500   -0.433078
# dtype: float64

# %% [markdown]
# Вычислите TSS, ESS, RSS

# %%
# TSS
res.centered_tss
# Out:
# np.float64(797.6674045328446)

# %%
# ESS
res.ess
# Out:
# np.float64(708.6473705860927)

# %%
# RSS
res.ssr
# Out:
# np.float64(89.02003394675182)

# %% [markdown]
# Вычислите R2
#  и adj.R2

# %%
# R^2
res.rsquared
# Out:
# np.float64(0.8883995592136718)

# %%
# adj R^2
res.rsquared_adj
# Out:
# np.float64(0.887806990501532)

# %%
# стандартная ошибка регрессии
res.scale**0.5
# Out:
# np.float64(0.3969352367913945)

# %% [markdown]
# 1.7 Cost equation (in levels)
# Для датасета Electricity рассмотрим регрессию cost на q, q2, pk, pf, pl
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
# импорт данных из файла как DataFrame
df = pd.read_csv('Electricity (1).csv')

# %%
# спецификация модели через формулу
mod = ols(formula='cost~1+q+I(q ** 2)+pk+pf+pl', data=df)
# подгонка модели
res = mod.fit()

# %%
res.params.round(2)
# Out:
# Intercept   -81.36
# q             0.00
# I(q ** 2)     0.00
# pk            0.37
# pf            0.95
# pl            0.00
# dtype: float64

# %% [markdown]
# Для наблюдений с индексом 1, 16, 28, 47, 57, 93 найдите фактическое значение зависимой переменной, предсказанное значение и остатки.

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [ 1, 16, 28, 47, 57, 93]

# %%
# Фактические значения
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
df['cost'].iloc[ind]
# Out:
# 1      3.0427
# 16     5.5971
# 28     7.4395
# 47    28.7861
# 57    41.9016
# 93     9.4674
# Name: cost, dtype: float64

# %%
# Предсказанные значения
res.fittedvalues[ind]
# Out:
# 1     -2.512127
# 16     2.746666
# 28    -2.269194
# 47    34.228149
# 57    43.941326
# 93    -4.009281
# dtype: float64

# %%
# Остатки.
#можно округлить x.round(2) or round(x, 2)
res.resid[ind]
# Out:
# 1      5.554827
# 16     2.850434
# 28     9.708694
# 47    -5.442049
# 57    -2.039726
# 93    13.476681
# dtype: float64

# %%
# TSS
res.centered_tss
# Out:
# 1189954.2094165923

# %%
res.ess
# Out:
# 1143993.9558765874

# %%
res.ssr
# Out:
# 45960.25354000478

# %%
# R^2
res.rsquared
# Out:
# 0.9613764519875617

# %%
res.rsquared_adj
# Out:
# 0.9601059405397842

# %%
res.scale**0.5
# Out:
# 17.388792053474525

# %% [markdown]
# 1.8 Cost equation (in logs)
# Для датасета Electricity рассмотрим регрессию log(cost) на log(q), log2(q), log(pk), log(pf), log(pl)
#
# Найтиде коэффициенты подогнанной модели. Ответ округлите до 2-х десятичных знаков.
#
# Ответ:

# %%
# спецификация модели через формулу
mod = ols(formula='np.log(cost)~1+np.log(q)+I(np.log(q)**2)+np.log(pk)+np.log(pf)+np.log(pl)', data=df)
# подгонка модели
res = mod.fit()

# %%
res.params.round(2)
# Out:
# Intercept           -6.74
# np.log(q)            0.40
# I(np.log(q) ** 2)    0.03
# np.log(pk)           0.16
# np.log(pf)           0.68
# np.log(pl)           0.15
# dtype: float64

# %%
# задаем индексы для каких наблюдений надо получиь соответсвующие значения, если говорят про какие-то наблюдение, то это тоже индексы
# первое наблюдение нулевое
ind = [  1, 16, 28, 47, 57, 93]

# %%
# Фактические значения
# выбор для зависимой переменной, дф - столбец, илок - строки интересующие. индекс строки - левый, правое значение
np.log(df['cost']).iloc[ind].round(
# Out:
# 1     1.112745
# 16    1.722249
# 28    2.006804
# 47    3.359893
# 57    3.735324
# 93    2.247854
# Name: cost, dtype: float64
